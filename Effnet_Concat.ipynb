# %% [markdown]
# # CSC413 Project: GeoGuessr!

# %% [markdown]
# ## A bunch of imports

# %%
from typing import *
from collections import defaultdict
from PIL import Image
from IPython.display import display
from glob import glob
import re
import os
from random import shuffle
import time
from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection
import xml.etree.ElementTree as ET
import numpy as np
 
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import ToTensor
from torchvision import transforms, models
# !pip install efficientnet_pytorch
from efficientnet_pytorch import EfficientNet
# Out:
# Collecting efficientnet_pytorch
#   Downloading https://files.pythonhosted.org/packages/2e/a0/dd40b50aebf0028054b6b35062948da01123d7be38d08b6b1e5435df6363/efficientnet_pytorch-0.7.1.tar.gz
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet_pytorch) (1.8.1+cu101)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet_pytorch) (3.7.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet_pytorch) (1.19.5)
# Building wheels for collected packages: efficientnet-pytorch
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-cp37-none-any.whl size=16443 sha256=bc68cd722f1e0fb70d773c5d8816d4680cc89546ac039cdf8739955fa0d377c9
#   Stored in directory: /root/.cache/pip/wheels/84/27/aa/c46d23c4e8cc72d41283862b1437e0b3ad318417e8ed7d5921
# Successfully built efficientnet-pytorch
# Installing collected packages: efficientnet-pytorch
# Successfully installed efficientnet-pytorch-0.7.1

# %% [markdown]
# ## Visualizing stuff

# %%
torch.manual_seed(0)
# Reverse normalization
inv_normalize = transforms.Normalize(
    mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225],
    std=[1/0.229, 1/0.224, 1/0.225]
)

def visualize_example(tup, batch_idx=0, invert=False):
  bs, n, c, height, width = tup.shape
  dst = Image.new("RGB", (4*width, height))
  tup = tuple(tup[batch_idx, i] for i in range(4))

  if invert: 
    tup = tuple(inv_normalize(t) for t in tup)
  dst.paste(transforms.ToPILImage()(tup[0]), (0, 0))
  dst.paste(transforms.ToPILImage()(tup[1]), (width, 0))
  dst.paste(transforms.ToPILImage()(tup[2]), (width*2, 0))
  dst.paste(transforms.ToPILImage()(tup[3]), (width*3, 0))
  display(dst)


def get_borders(states_file):
    """ From original DeepGeo paper """
    #init
    borders = []

    # get state borders  
    tree = ET.parse(states_file)
    root = tree.getroot()
    count = 0
    for child in root:
        count+=1
        stateBorder = np.empty((0,2),dtype=np.float64)
        for point in child:
            stateBorder = np.append(stateBorder,np.array([[point.attrib['lng'], point.attrib['lat']]]),axis=0)
        borders.append(stateBorder)

    return borders

def get_labels(states_file):
    """ From original DeepGeo paper """
    labels = []

    # get state borders  
    tree = ET.parse(states_file)
    root = tree.getroot()
    count = 0
    for child in root:
        labels.append(child.attrib['name'])

    return labels

def plot_data_samples():
    coords = []
    for d in glob("training/*"):
      with open(f"{d}/info.txt", "r") as f:
        coords.extend([l.split(" ")[-3:-1] for l in f.readlines() if not l.startswith("/mnt") and not l.startswith("//mnt")])
    coords = [coord for coord in coords if len(coord)==2 and coord[0] and coord[1]]
    borders = get_borders("Canada.kml")
    labels = get_labels("Canada.kml")
    
    bord_arr = np.concatenate(borders).astype(float)
    fig, ax = plt.subplots()
    lines = LineCollection([bord_arr])
    ax.add_collection(lines)
    coords_arr = np.array(coords).astype(float)
    ax.scatter(coords_arr[:,1], coords_arr[:,0], s=1)
    ax.autoscale()
    plt.show()

# %% [markdown]
# ## Load in the data

# %%
# 1k Canada dataset
# !gdown --id 1RQHBfuojV_gv7cFO38AXXPOG34cYyGeK

# Min 3.5k Canada dataset
# !gdown --id 1JjbMa-n_jb0X60KNk4h12ePjynTwMgwO

# Canadian provinces
# !gdown --id 1SMxaLVYSDKS3AT3T8f_BgkWYBzWnrCqM
# !mkdir training
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1RQHBfuojV_gv7cFO38AXXPOG34cYyGeK
# To: /content/1kimages090180270.tar.gz
# 420MB [00:04, 101MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1SMxaLVYSDKS3AT3T8f_BgkWYBzWnrCqM
# To: /content/Canada.kml
# 100% 38.3k/38.3k [00:00<00:00, 55.5MB/s]

# %%
# %%capture
# !tar -xzvf 1kimages090180270.tar.gz -C training
# !tar -xzvf min3kimages.tar.gz -C training
# !for d in training/images*; do mv "${d}" "training/`basename "${d}" | sed -e 's/images//g' | sed -e 's/\s//g'`"; done
# !rm -rf 1kimages090180270.tar.gz
# !rm -rf min3kimages.tar.gz

# %%
data = defaultdict(list)

def get_image_ids(province: str) -> List[str]:
  images = glob(f"training/{province}/*.jpg")
  ids_no_angle = [re.sub('_[\\d]*.jpg', '', f) for f in images]
  return ids_no_angle 

def stitch_images_and_save(image_base_path: str) -> None:
  img = Image.new("RGB", (512, 512))
  img_0 = Image.open(f"{image_base_path}_0.jpg")
  img_90 = Image.open(f"{image_base_path}_90.jpg")
  img_180 = Image.open(f"{image_base_path}_180.jpg")
  img_270 = Image.open(f"{image_base_path}_270.jpg")
  img.paste(img_0, (0, 0))
  img.paste(img_90, (256, 0))
  img.paste(img_180, (0, 256))
  img.paste(img_270, (256, 256))

  new_name = f"{image_base_path}_stitched.jpg"
  img.save(new_name)
  data[image_base_path.split("/")[-2]].append(new_name)

# %% [markdown]
# ## A custom dataset

# %%
preprocess =  transforms.Compose([
                    transforms.Resize(224),
                    #transforms.CenterCrop(224),
                    transforms.ToTensor(),
                    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
                    ])
class GeoDataset(Dataset):
  """
  Holds a bunch of (N, E, S, W) quadruplets of examples along with the corresponding province labels.

  # Todo: maybe add transform?
  """
  def __init__(self, index_file, transform=None, shuf=False):
    self.index_file = index_file
    self.transform = transform

    self.labels = {k: i for i, k in enumerate(index_file.keys())}

    # Data has (N, E, S, W, province)
    self.data = []
    for prov, tups in index_file.items():
      for tup in tups:
        self.data.append((*tup, prov))
    if shuf:
      shuffle(self.data)

  def __len__(self) -> int:
    return len(self.data)

  def __getitem__(self, idx):
    """
    Returns: 
      (N, E, S, W) images, province
    tuple
    """
    tup = self.data[idx]
    images = torch.cat(tuple(preprocess(Image.open(t)).unsqueeze(0) for t in tup[:-1]), 0) 
    return (images, self.labels[tup[-1]])

# %%
index_files = defaultdict(list)

for province in glob("training/*"):
  name = os.path.basename(province)
  for image in get_image_ids(name):
    # stitch_images_and_save(image)
    index_files[name].append(tuple(f"{image}_{angle}.jpg" for angle in ("0", "90", "180", "270")))

# %%
dataset = GeoDataset(index_files)
length = len(dataset)

train_frac = 0.8
val_frac = test_frac = 0.1
train_len = int(train_frac*length)
val_len = test_len = int(val_frac*length)
train_set, val_set, test_set = torch.utils.data.random_split(dataset, [train_len, val_len, test_len])

#train_set = torch.utils.data.Subset(dataset, list(range(0, int(train_frac*length))))
#val_set = torch.utils.data.Subset(dataset, list(range(len(train_set), len(train_set)+int(val_frac*length)+1)))
#test_set = torch.utils.data.Subset(dataset, list(range(len(train_set)+len(val_set), len(train_set)+len(val_set) + int(test_frac*length)+1)))
train_loader = DataLoader(train_set, batch_size=32, shuffle=True, num_workers=2, prefetch_factor=8)
val_loader = DataLoader(val_set, batch_size=32, shuffle=True, num_workers=2, prefetch_factor=8)
test_loader = DataLoader(test_set, batch_size=32, shuffle=True, num_workers=2, prefetch_factor=8)

# %%
images, labels = next(iter(test_loader))

# %% [markdown]
# # What the data looks like
# We have in the top image the unnormalized image.
#
# The image below that is the same image, but with normalization as a preprocessing step before adding it to the model.
#
# The third image contains a scatterplot of where street view data samples were collected across Canada. Because most upper parts of Canada are sparsely populated, not much data was collected; the Thunder Bay area in Ontario, for example, is one of the northmost areas that have data...most of the data in Ontario is in the GTA region.
#
# Note: the map looks very crude to simplify the data collection and classification process because it didn't really matter how fine the details were on the borders since street view doesn't gather images right by the oceanside.

# %%
visualize_example(images, 10, True)
visualize_example(images, 10, False)
plot_data_samples()
# Out:
# <PIL.Image.Image image mode=RGB size=896x224 at 0x7F4B4018BE90>
# <PIL.Image.Image image mode=RGB size=896x224 at 0x7F4B39D84FD0>

# %% [markdown]
# ## Code to actually do the training logic

# %% [markdown]
# ## EfficientNet

# %%
device = torch.device("cuda" if torch.cuda.is_available() 
                                  else "cpu")
model = EfficientNet.from_pretrained('efficientnet-b0')
for param in model.parameters():
    param.requires_grad = False
    
model._fc = nn.Sequential(nn.Linear(1280, 256),
                                 nn.ReLU(),
                                 nn.Dropout(0.2),
                                 nn.Linear(256, 10),
                                 nn.LogSoftmax(dim=1))
criterion = nn.NLLLoss()
optimizer = torch.optim.Adam(model._fc.parameters(), lr=0.003)
model.to(device)

epochs = 1
steps = 0
running_loss = 0
print_every = 10
train_losses, test_losses, accs = [], [], []

model.eval()
for epoch in range(epochs):
      for i, data in enumerate(train_loader):
          inputs, labels = data
          steps += 1
          inputs, labels = inputs.to(device), labels.to(device)
          optimizer.zero_grad()

          new_in = torch.cat([inputs[:,0,...], inputs[:,1,...], inputs[:,2,...], inputs[:,3,...]], dim = 3)
          n_logps = model.forward(new_in)
          n_loss = criterion(n_logps, labels)
          n_loss.backward()

          loss = n_loss

          optimizer.step()
          running_loss += loss.item()
          
          if steps % print_every == 0:
              test_loss = 0
              accuracy = 0
              model.eval()
              with torch.no_grad():
                  for inputs, labels in test_loader:
                      inputs, labels = inputs.to(device), labels.to(device)

                      new_in = torch.cat([inputs[:,0,...], inputs[:,1,...], inputs[:,2,...], inputs[:,3,...]], dim = 3)
                      n_logps = model.forward(new_in)
                      n_batch_loss = criterion(n_logps, labels)
                      test_loss += n_batch_loss.item()

                      logps = n_logps
                      
                      ps = torch.exp(logps)
                      top_p, top_class = ps.topk(1, dim=1)
                      equals = top_class == labels.view(*top_class.shape)
                      accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
              train_losses.append(running_loss/len(train_loader))
              test_losses.append(test_loss/len(test_loader))     
              accs.append(accuracy/len(test_loader))               
              print(f"Epoch {epoch+1}/{epochs}.. "
                    f"Train loss: {running_loss/print_every:.3f}.. "
                    f"Test loss: {test_loss/len(test_loader):.3f}.. "
                    f"Test accuracy: {accuracy/len(test_loader):.3f}")
              
              running_loss = 0
              model.train()
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b0-355c32eb.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b0-355c32eb.pth
# HBox(children=(FloatProgress(value=0.0, max=21388428.0), HTML(value='')))
# Loaded pretrained weights for efficientnet-b0
# Epoch 1/1.. Train loss: 2.280.. Test loss: 2.120.. Test accuracy: 0.231
# Epoch 1/1.. Train loss: 2.252.. Test loss: 2.474.. Test accuracy: 0.119
# Epoch 1/1.. Train loss: 2.125.. Test loss: 2.810.. Test accuracy: 0.106
# Epoch 1/1.. Train loss: 2.091.. Test loss: 2.756.. Test accuracy: 0.111
# Epoch 1/1.. Train loss: 1.956.. Test loss: 2.798.. Test accuracy: 0.117
# Epoch 1/1.. Train loss: 1.868.. Test loss: 2.697.. Test accuracy: 0.126
# Epoch 1/1.. Train loss: 1.831.. Test loss: 2.832.. Test accuracy: 0.120
# Epoch 1/1.. Train loss: 1.833.. Test loss: 2.286.. Test accuracy: 0.221
# Epoch 1/1.. Train loss: 1.741.. Test loss: 2.247.. Test accuracy: 0.178
# Epoch 1/1.. Train loss: 1.832.. Test loss: 2.281.. Test accuracy: 0.210
# Epoch 1/1.. Train loss: 1.711.. Test loss: 2.370.. Test accuracy: 0.190
# Epoch 1/1.. Train loss: 1.699.. Test loss: 1.999.. Test accuracy: 0.311
# Epoch 1/1.. Train loss: 1.654.. Test loss: 2.060.. Test accuracy: 0.279
# Epoch 1/1.. Train loss: 1.639.. Test loss: 1.955.. Test accuracy: 0.273
# Epoch 1/1.. Train loss: 1.586.. Test loss: 1.978.. Test accuracy: 0.311
# Epoch 1/1.. Train loss: 1.584.. Test loss: 1.703.. Test accuracy: 0.376
# Epoch 1/1.. Train loss: 1.633.. Test loss: 1.851.. Test accuracy: 0.335
# Epoch 1/1.. Train loss: 1.589.. Test loss: 1.669.. Test accuracy: 0.407
# Epoch 1/1.. Train loss: 1.563.. Test loss: 1.585.. Test accuracy: 0.428
# Epoch 1/1.. Train loss: 1.550.. Test loss: 1.689.. Test accuracy: 0.388
# Epoch 1/1.. Train loss: 1.566.. Test loss: 1.557.. Test accuracy: 0.434
# Epoch 1/1.. Train loss: 1.635.. Test loss: 1.469.. Test accuracy: 0.473
# Epoch 1/1.. Train loss: 1.482.. Test loss: 1.545.. Test accuracy: 0.438
# Epoch 1/1.. Train loss: 1.431.. Test loss: 1.392.. Test accuracy: 0.498
# Epoch 1/1.. Train loss: 1.601.. Test loss: 1.444.. Test accuracy: 0.463
# Epoch 1/1.. Train loss: 1.531.. Test loss: 1.437.. Test accuracy: 0.473
# Epoch 1/1.. Train loss: 1.592.. Test loss: 1.376.. Test accuracy: 0.508
# Epoch 1/1.. Train loss: 1.419.. Test loss: 1.376.. Test accuracy: 0.511
# Epoch 1/1.. Train loss: 1.522.. Test loss: 1.333.. Test accuracy: 0.517
# Epoch 1/1.. Train loss: 1.421.. Test loss: 1.330.. Test accuracy: 0.521
# Epoch 1/1.. Train loss: 1.342.. Test loss: 1.321.. Test accuracy: 0.523
# Epoch 1/1.. Train loss: 1.566.. Test loss: 1.326.. Test accuracy: 0.524
# Epoch 1/1.. Train loss: 1.479.. Test loss: 1.307.. Test accuracy: 0.532
# Epoch 1/1.. Train loss: 1.509.. Test loss: 1.327.. Test accuracy: 0.534
# Epoch 1/1.. Train loss: 1.424.. Test loss: 1.323.. Test accuracy: 0.528
# Epoch 1/1.. Train loss: 1.422.. Test loss: 1.298.. Test accuracy: 0.519
# Epoch 1/1.. Train loss: 1.376.. Test loss: 1.254.. Test accuracy: 0.550
# Epoch 1/1.. Train loss: 1.410.. Test loss: 1.258.. Test accuracy: 0.544
# Epoch 1/1.. Train loss: 1.411.. Test loss: 1.282.. Test accuracy: 0.543
# Epoch 1/1.. Train loss: 1.556.. Test loss: 1.321.. Test accuracy: 0.531
# Epoch 1/1.. Train loss: 1.491.. Test loss: 1.282.. Test accuracy: 0.546
# Epoch 1/1.. Train loss: 1.473.. Test loss: 1.260.. Test accuracy: 0.544
# Epoch 1/1.. Train loss: 1.391.. Test loss: 1.210.. Test accuracy: 0.569
# Epoch 1/1.. Train loss: 1.398.. Test loss: 1.228.. Test accuracy: 0.570
# Epoch 1/1.. Train loss: 1.335.. Test loss: 1.209.. Test accuracy: 0.581
# Epoch 1/1.. Train loss: 1.470.. Test loss: 1.268.. Test accuracy: 0.546
# Epoch 1/1.. Train loss: 1.360.. Test loss: 1.276.. Test accuracy: 0.534
# Epoch 1/1.. Train loss: 1.484.. Test loss: 1.264.. Test accuracy: 0.569
# Epoch 1/1.. Train loss: 1.373.. Test loss: 1.219.. Test accuracy: 0.581
# Epoch 1/1.. Train loss: 1.332.. Test loss: 1.242.. Test accuracy: 0.564
# Epoch 1/1.. Train loss: 1.475.. Test loss: 1.317.. Test accuracy: 0.527
# Epoch 1/1.. Train loss: 1.408.. Test loss: 1.237.. Test accuracy: 0.583
# Epoch 1/1.. Train loss: 1.533.. Test loss: 1.281.. Test accuracy: 0.554
# Epoch 1/1.. Train loss: 1.448.. Test loss: 1.257.. Test accuracy: 0.566
# Epoch 1/1.. Train loss: 1.397.. Test loss: 1.246.. Test accuracy: 0.560
# Epoch 1/1.. Train loss: 1.402.. Test loss: 1.254.. Test accuracy: 0.566
# Epoch 1/1.. Train loss: 1.463.. Test loss: 1.285.. Test accuracy: 0.548
# Epoch 1/1.. Train loss: 1.416.. Test loss: 1.229.. Test accuracy: 0.572
# Epoch 1/1.. Train loss: 1.286.. Test loss: 1.234.. Test accuracy: 0.560
# Epoch 1/1.. Train loss: 1.423.. Test loss: 1.192.. Test accuracy: 0.590
# Epoch 1/1.. Train loss: 1.272.. Test loss: 1.150.. Test accuracy: 0.606
# Epoch 1/1.. Train loss: 1.437.. Test loss: 1.190.. Test accuracy: 0.587
# Epoch 1/1.. Train loss: 1.436.. Test loss: 1.219.. Test accuracy: 0.591
# Epoch 1/1.. Train loss: 1.322.. Test loss: 1.208.. Test accuracy: 0.589
# Epoch 1/1.. Train loss: 1.414.. Test loss: 1.202.. Test accuracy: 0.604
# Epoch 1/1.. Train loss: 1.230.. Test loss: 1.240.. Test accuracy: 0.600
# Epoch 1/1.. Train loss: 1.455.. Test loss: 1.205.. Test accuracy: 0.590
# Epoch 1/1.. Train loss: 1.243.. Test loss: 1.142.. Test accuracy: 0.611
# Epoch 1/1.. Train loss: 1.348.. Test loss: 1.168.. Test accuracy: 0.612
# Epoch 1/1.. Train loss: 1.342.. Test loss: 1.174.. Test accuracy: 0.606
# Epoch 1/1.. Train loss: 1.227.. Test loss: 1.110.. Test accuracy: 0.616
# Epoch 1/1.. Train loss: 1.255.. Test loss: 1.182.. Test accuracy: 0.600
# Epoch 1/1.. Train loss: 1.374.. Test loss: 1.146.. Test accuracy: 0.598
# Epoch 1/1.. Train loss: 1.305.. Test loss: 1.179.. Test accuracy: 0.570
# Epoch 1/1.. Train loss: 1.361.. Test loss: 1.125.. Test accuracy: 0.603
# Epoch 1/1.. Train loss: 1.247.. Test loss: 1.215.. Test accuracy: 0.573
# Epoch 1/1.. Train loss: 1.304.. Test loss: 1.151.. Test accuracy: 0.609
# Epoch 1/1.. Train loss: 1.343.. Test loss: 1.123.. Test accuracy: 0.616
# Epoch 1/1.. Train loss: 1.288.. Test loss: 1.153.. Test accuracy: 0.606
# Epoch 1/1.. Train loss: 1.166.. Test loss: 1.152.. Test accuracy: 0.619
# Epoch 1/1.. Train loss: 1.188.. Test loss: 1.107.. Test accuracy: 0.628
# Epoch 1/1.. Train loss: 1.215.. Test loss: 1.159.. Test accuracy: 0.612
# Epoch 1/1.. Train loss: 1.372.. Test loss: 1.145.. Test accuracy: 0.612
# Epoch 1/1.. Train loss: 1.332.. Test loss: 1.192.. Test accuracy: 0.599
# Epoch 1/1.. Train loss: 1.274.. Test loss: 1.152.. Test accuracy: 0.612
# Epoch 1/1.. Train loss: 1.334.. Test loss: 1.120.. Test accuracy: 0.645
# Epoch 1/1.. Train loss: 1.250.. Test loss: 1.145.. Test accuracy: 0.606
# Epoch 1/1.. Train loss: 1.300.. Test loss: 1.084.. Test accuracy: 0.639
# Epoch 1/1.. Train loss: 1.258.. Test loss: 1.104.. Test accuracy: 0.608
# Epoch 1/1.. Train loss: 1.256.. Test loss: 1.041.. Test accuracy: 0.646
# Epoch 1/1.. Train loss: 1.286.. Test loss: 1.036.. Test accuracy: 0.643
# Epoch 1/1.. Train loss: 1.176.. Test loss: 1.093.. Test accuracy: 0.627
# Epoch 1/1.. Train loss: 1.185.. Test loss: 1.108.. Test accuracy: 0.619
# Epoch 1/1.. Train loss: 1.387.. Test loss: 1.111.. Test accuracy: 0.610
# Epoch 1/1.. Train loss: 1.226.. Test loss: 1.125.. Test accuracy: 0.614
# Epoch 1/1.. Train loss: 1.195.. Test loss: 1.142.. Test accuracy: 0.613
# Epoch 1/1.. Train loss: 1.343.. Test loss: 1.105.. Test accuracy: 0.648
# Epoch 1/1.. Train loss: 1.158.. Test loss: 1.071.. Test accuracy: 0.642
# Epoch 1/1.. Train loss: 1.226.. Test loss: 1.079.. Test accuracy: 0.631
# Epoch 1/1.. Train loss: 1.323.. Test loss: 1.088.. Test accuracy: 0.632

# %%
torch.save(model, "effnetb0concat.pt")

# %% [markdown]
# ## Predictions from pretrained guy

# %%
#pretrained = models.resnet18(pretrained=False)
#pretrained.fc = nn.Sequential(nn.Linear(512, 256),
#                                 nn.ReLU(),
#                                 nn.Dropout(0.2),
#                                 nn.Linear(256, 10),
#                                 nn.LogSoftmax(dim=1))
#pretrained.load_state_dict(torch.load("resnetsmalldataset"))
# pretrained = EfficientNet.from_pretrained('efficientnet-b0')
    
# pretrained._fc = nn.Sequential(nn.Linear(1792, 256),
#                                  nn.ReLU(),
#                                  nn.Dropout(0.2),
#                                  nn.Linear(256, 10),
#                                  nn.LogSoftmax(dim=1))
pretrained = torch.load("effnetb0(1).pt")
pretrained.eval()
images, labels = next(iter(test_loader))

device = torch.device("cuda" if torch.cuda.is_available() 
                                  else "cpu")
images, labels = images.to(device), labels.to(device)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-1a0d11308a56> in <module>()
#      13 #                                  nn.Linear(256, 10),
#      14 #                                  nn.LogSoftmax(dim=1))
# ---> 15 pretrained = torch.load("effnetb0(1).pt")
#      16 pretrained.eval()
#      17 images, labels = next(iter(test_loader))
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     577         pickle_load_args['encoding'] = 'utf-8'
#     578
# --> 579     with _open_file_like(f, 'rb') as opened_file:
#     580         if _is_zipfile(opened_file):
#     581             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'effnetb0(1).pt'

# %%
with torch.no_grad():
  visualize_example(images, 10, True)
  smax = pretrained.forward(images[10])
  comb = smax.mean(axis=0)
  preds = smax.argmax(axis=1)
  comb_preds = comb.argmax()
  real_labels = dict((v, k) for k, v in dataset.labels.items())
  print(f"Actual province: {real_labels[labels[10].item()]}")
  print(f"North prediction: {real_labels[preds[0].item()]}")
  print(f"East prediction: {real_labels[preds[1].item()]}")
  print(f"South prediction: {real_labels[preds[2].item()]}")
  print(f"West prediction: {real_labels[preds[3].item()]}")
  print(f"Combined prediction: {real_labels[comb_preds.item()]}")

# %%
with torch.no_grad():
  visualize_example(images, 5, True)
  smax = pretrained.forward(images[5])
  comb = smax.mean(axis=0)
  preds = smax.argmax(axis=1)
  comb_preds = comb.argmax()
  real_labels = dict((v, k) for k, v in dataset.labels.items())
  print(f"Actual province: {real_labels[labels[5].item()]}")
  print(f"North prediction: {real_labels[preds[0].item()]}")
  print(f"East prediction: {real_labels[preds[1].item()]}")
  print(f"South prediction: {real_labels[preds[2].item()]}")
  print(f"West prediction: {real_labels[preds[3].item()]}")
  print(f"Combined prediction: {real_labels[comb_preds.item()]}")

# %%
with torch.no_grad():
  visualize_example(images, 20, True)
  smax = pretrained.forward(images[20])
  comb = smax.mean(axis=0)
  preds = smax.argmax(axis=1)
  comb_preds = comb.argmax()
  real_labels = dict((v, k) for k, v in dataset.labels.items())
  print(f"Actual province: {real_labels[labels[20].item()]}")
  print(f"North prediction: {real_labels[preds[0].item()]}")
  print(f"East prediction: {real_labels[preds[1].item()]}")
  print(f"South prediction: {real_labels[preds[2].item()]}")
  print(f"West prediction: {real_labels[preds[3].item()]}")
  print(f"Combined prediction: {real_labels[comb_preds.item()]}")

# %%
pretrained = model
pred_counts = defaultdict(int)
pred_correct = defaultdict(int)
real_labels = dict((v, k) for k, v in dataset.labels.items())

for i, (inputs, labels) in enumerate(val_loader):
    inputs, labels = inputs.cuda(), labels.cuda()

    n_smax = pretrained.forward(inputs[:,0,...])
    e_smax = pretrained.forward(inputs[:,1,...])
    s_smax = pretrained.forward(inputs[:,2,...])
    w_smax = pretrained.forward(inputs[:,3,...])
    comb = (n_smax+e_smax+s_smax+w_smax)/4

    n_pred = n_smax.argmax(axis=1)
    e_pred = e_smax.argmax(axis=1)
    s_pred = s_smax.argmax(axis=1)
    w_pred = w_smax.argmax(axis=1)
    comb_pred = comb.argmax(axis=1)
    

    correct = comb_pred == labels
    for j, corr in enumerate(correct):
        pred_correct[real_labels[labels[j].item()]] += int(corr)
        pred_counts[real_labels[labels[j].item()]] += 1

print(pred_counts)
print(pred_correct)
for k, v in pred_counts.items():
    print(f"{k} accuracy: {pred_correct[k]/v:.4f}")
print(f"Overall accuracy: {sum(pred_correct.values())/sum(pred_counts.values())}")
# Out:
# defaultdict(<class 'int'>, {'Alberta': 398, 'Saskatchewan': 422, 'BritishColumbia': 420, 'NewfoundlandandLabrador': 413, 'Manitoba': 389, 'Ontario': 360, 'PEI': 397, 'Quebec': 369, 'NovaScotia': 413, 'NewBrunswick': 419})
# defaultdict(<class 'int'>, {'Alberta': 246, 'Saskatchewan': 203, 'BritishColumbia': 270, 'NewfoundlandandLabrador': 279, 'Manitoba': 239, 'Ontario': 159, 'PEI': 326, 'Quebec': 103, 'NovaScotia': 295, 'NewBrunswick': 176})
# Alberta accuracy: 0.6181
# Saskatchewan accuracy: 0.4810
# BritishColumbia accuracy: 0.6429
# NewfoundlandandLabrador accuracy: 0.6755
# Manitoba accuracy: 0.6144
# Ontario accuracy: 0.4417
# PEI accuracy: 0.8212
# Quebec accuracy: 0.2791
# NovaScotia accuracy: 0.7143
# NewBrunswick accuracy: 0.4200
# Overall accuracy: 0.574

# %% [markdown]
# # CSC413 Project: GeoGuessr!

# %% [markdown]
# ## A bunch of imports

# %%
from typing import *
from collections import defaultdict
from PIL import Image
from IPython.display import display
from glob import glob
import re
import os
from random import shuffle
import time
from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection
import xml.etree.ElementTree as ET
import numpy as np
 
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import ToTensor
from torchvision import transforms, models
# !pip install efficientnet_pytorch
from efficientnet_pytorch import EfficientNet
# Out:
# Collecting efficientnet_pytorch
#   Downloading https://files.pythonhosted.org/packages/2e/a0/dd40b50aebf0028054b6b35062948da01123d7be38d08b6b1e5435df6363/efficientnet_pytorch-0.7.1.tar.gz
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet_pytorch) (1.8.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet_pytorch) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet_pytorch) (3.7.4.3)
# Building wheels for collected packages: efficientnet-pytorch
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-cp37-none-any.whl size=16443 sha256=b0d9076958a7e4098a415344595fd4c6a4eb02cc1a59ac113104db3269fa1317
#   Stored in directory: /root/.cache/pip/wheels/84/27/aa/c46d23c4e8cc72d41283862b1437e0b3ad318417e8ed7d5921
# Successfully built efficientnet-pytorch
# Installing collected packages: efficientnet-pytorch
# Successfully installed efficientnet-pytorch-0.7.1

# %% [markdown]
# ## Visualizing stuff

# %%
# Reverse normalization
torch.manual_seed(0)
inv_normalize = transforms.Normalize(
    mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225],
    std=[1/0.229, 1/0.224, 1/0.225]
)

def visualize_example(tup, batch_idx=0, invert=False):
  bs, n, c, height, width = tup.shape
  dst = Image.new("RGB", (4*width, height))
  tup = tuple(tup[batch_idx, i] for i in range(4))

  if invert: 
    tup = tuple(inv_normalize(t) for t in tup)
  dst.paste(transforms.ToPILImage()(tup[0]), (0, 0))
  dst.paste(transforms.ToPILImage()(tup[1]), (width, 0))
  dst.paste(transforms.ToPILImage()(tup[2]), (width*2, 0))
  dst.paste(transforms.ToPILImage()(tup[3]), (width*3, 0))
  display(dst)


def get_borders(states_file):
    """ From original DeepGeo paper """
    #init
    borders = []

    # get state borders  
    tree = ET.parse(states_file)
    root = tree.getroot()
    count = 0
    for child in root:
        count+=1
        stateBorder = np.empty((0,2),dtype=np.float64)
        for point in child:
            stateBorder = np.append(stateBorder,np.array([[point.attrib['lng'], point.attrib['lat']]]),axis=0)
        borders.append(stateBorder)

    return borders

def get_labels(states_file):
    """ From original DeepGeo paper """
    labels = []

    # get state borders  
    tree = ET.parse(states_file)
    root = tree.getroot()
    count = 0
    for child in root:
        labels.append(child.attrib['name'])

    return labels

def plot_data_samples():
    coords = []
    for d in glob("training/*"):
      with open(f"{d}/info.txt", "r") as f:
        coords.extend([l.split(" ")[-3:-1] for l in f.readlines() if not l.startswith("/mnt") and not l.startswith("//mnt")])
    coords = [coord for coord in coords if len(coord)==2 and coord[0] and coord[1]]
    borders = get_borders("Canada.kml")
    labels = get_labels("Canada.kml")
    
    bord_arr = np.concatenate(borders).astype(float)
    fig, ax = plt.subplots()
    lines = LineCollection([bord_arr])
    ax.add_collection(lines)
    coords_arr = np.array(coords).astype(float)
    ax.scatter(coords_arr[:,1], coords_arr[:,0], s=1)
    ax.autoscale()
    plt.show()

# %% [markdown]
# ## Load in the data

# %%
# 1k Canada dataset
# !gdown --id 1RQHBfuojV_gv7cFO38AXXPOG34cYyGeK

# Min 3.5k Canada dataset
# !gdown --id 1JjbMa-n_jb0X60KNk4h12ePjynTwMgwO

# Canadian provinces
# !gdown --id 1SMxaLVYSDKS3AT3T8f_BgkWYBzWnrCqM
# !mkdir training
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1RQHBfuojV_gv7cFO38AXXPOG34cYyGeK
# To: /content/1kimages090180270.tar.gz
# 420MB [00:01, 213MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1SMxaLVYSDKS3AT3T8f_BgkWYBzWnrCqM
# To: /content/Canada.kml
# 100% 38.3k/38.3k [00:00<00:00, 5.20MB/s]

# %%
# %%capture
# !tar -xzvf 1kimages090180270.tar.gz -C training
# !tar -xzvf min3kimages.tar.gz -C training
# !for d in training/images*; do mv "${d}" "training/`basename "${d}" | sed -e 's/images//g' | sed -e 's/\s//g'`"; done
# !rm -rf 1kimages090180270.tar.gz
# !rm -rf min3kimages.tar.gz

# %%
data = defaultdict(list)

def get_image_ids(province: str) -> List[str]:
  images = glob(f"training/{province}/*.jpg")
  ids_no_angle = [re.sub('_[\\d]*.jpg', '', f) for f in images]
  return ids_no_angle 

def stitch_images_and_save(image_base_path: str) -> None:
  img = Image.new("RGB", (512, 512))
  img_0 = Image.open(f"{image_base_path}_0.jpg")
  img_90 = Image.open(f"{image_base_path}_90.jpg")
  img_180 = Image.open(f"{image_base_path}_180.jpg")
  img_270 = Image.open(f"{image_base_path}_270.jpg")
  img.paste(img_0, (0, 0))
  img.paste(img_90, (256, 0))
  img.paste(img_180, (0, 256))
  img.paste(img_270, (256, 256))

  new_name = f"{image_base_path}_stitched.jpg"
  img.save(new_name)
  data[image_base_path.split("/")[-2]].append(new_name)

# %% [markdown]
# ## A custom dataset

# %%
preprocess =  transforms.Compose([
                    transforms.Resize(224),
                    #transforms.CenterCrop(224),
                    transforms.ToTensor(),
                    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
                    ])
class GeoDataset(Dataset):
  """
  Holds a bunch of (N, E, S, W) quadruplets of examples along with the corresponding province labels.

  # Todo: maybe add transform?
  """
  def __init__(self, index_file, transform=None, shuf=False):
    self.index_file = index_file
    self.transform = transform

    self.labels = {k: i for i, k in enumerate(index_file.keys())}

    # Data has (N, E, S, W, province)
    self.data = []
    for prov, tups in index_file.items():
      for tup in tups:
        self.data.append((*tup, prov))
    if shuf:
      shuffle(self.data)

  def __len__(self) -> int:
    return len(self.data)

  def __getitem__(self, idx):
    """
    Returns: 
      (N, E, S, W) images, province
    tuple
    """
    tup = self.data[idx]
    images = torch.cat(tuple(preprocess(Image.open(t)).unsqueeze(0) for t in tup[:-1]), 0) 
    return (images, self.labels[tup[-1]])

# %%
index_files = defaultdict(list)

for province in glob("training/*"):
  name = os.path.basename(province)
  for image in get_image_ids(name):
    # stitch_images_and_save(image)
    index_files[name].append(tuple(f"{image}_{angle}.jpg" for angle in ("0", "90", "180", "270")))

# %%
dataset = GeoDataset(index_files)
length = len(dataset)

train_frac = 0.8
val_frac = test_frac = 0.1
train_len = int(train_frac*length)
val_len = test_len = int(val_frac*length)
train_set, val_set, test_set = torch.utils.data.random_split(dataset, [train_len, val_len, test_len])

#train_set = torch.utils.data.Subset(dataset, list(range(0, int(train_frac*length))))
#val_set = torch.utils.data.Subset(dataset, list(range(len(train_set), len(train_set)+int(val_frac*length)+1)))
#test_set = torch.utils.data.Subset(dataset, list(range(len(train_set)+len(val_set), len(train_set)+len(val_set) + int(test_frac*length)+1)))
train_loader = DataLoader(train_set, batch_size=32, shuffle=True, num_workers=2, prefetch_factor=8)
val_loader = DataLoader(val_set, batch_size=32, shuffle=True, num_workers=2, prefetch_factor=8)
test_loader = DataLoader(test_set, batch_size=32, shuffle=True, num_workers=2, prefetch_factor=8)

# %%
images, labels = next(iter(test_loader))

# %% [markdown]
# # What the data looks like
# We have in the top image the unnormalized image.
#
# The image below that is the same image, but with normalization as a preprocessing step before adding it to the model.
#
# The third image contains a scatterplot of where street view data samples were collected across Canada. Because most upper parts of Canada are sparsely populated, not much data was collected; the Thunder Bay area in Ontario, for example, is one of the northmost areas that have data...most of the data in Ontario is in the GTA region.
#
# Note: the map looks very crude to simplify the data collection and classification process because it didn't really matter how fine the details were on the borders since street view doesn't gather images right by the oceanside.

# %%
visualize_example(images, 10, True)
visualize_example(images, 10, False)
plot_data_samples()
# Out:
# <PIL.Image.Image image mode=RGB size=896x224 at 0x7F4A74D40E90>
# <PIL.Image.Image image mode=RGB size=896x224 at 0x7F4A76806F90>

# %% [markdown]
# ## Code to actually do the training logic

# %% [markdown]
# ## EfficientNet

# %%
device = torch.device("cuda" if torch.cuda.is_available() 
                                  else "cpu")
model = EfficientNet.from_pretrained('efficientnet-b0')
for param in model.parameters():
    param.requires_grad = False
    
model._fc = nn.Sequential(nn.Linear(1280, 256),
                                 nn.ReLU(),
                                 nn.Dropout(0.2),
                                 nn.Linear(256, 10),
                                 nn.LogSoftmax(dim=1))
criterion = nn.NLLLoss()
optimizer = torch.optim.Adam(model._fc.parameters(), lr=0.003)
model.to(device)

epochs = 1
steps = 0
running_loss = 0
print_every = 10
train_losses, test_losses, accs = [], [], []

model.eval()
for epoch in range(epochs):
      for i, data in enumerate(train_loader):
          inputs, labels = data
          steps += 1
          inputs, labels = inputs.to(device), labels.to(device)
          optimizer.zero_grad()

          n_logps = model.forward(inputs[:,0,...])
          n_loss = criterion(n_logps, labels)
          n_loss.backward()

          e_logps = model.forward(inputs[:,1,...])
          e_loss = criterion(e_logps, labels)
          e_loss.backward()

          s_logps = model.forward(inputs[:,2,...])
          s_loss = criterion(s_logps, labels)
          s_loss.backward()

          w_logps = model.forward(inputs[:,3,...])
          w_loss = criterion(w_logps, labels)
          w_loss.backward()

          loss = n_loss + e_loss + s_loss + w_loss

          optimizer.step()
          running_loss += loss.item()
          
          if steps % print_every == 0:
              test_loss = 0
              accuracy = 0
              model.eval()
              with torch.no_grad():
                  for inputs, labels in test_loader:
                      inputs, labels = inputs.to(device), labels.to(device)

                      n_logps = model.forward(inputs[:,0,...])
                      n_batch_loss = criterion(n_logps, labels)
                      test_loss += n_batch_loss.item()

                      e_logps = model.forward(inputs[:,1,...])
                      e_batch_loss = criterion(e_logps, labels)
                      test_loss += e_batch_loss.item()

                      s_logps = model.forward(inputs[:,2,...])
                      s_batch_loss = criterion(s_logps, labels)
                      test_loss += s_batch_loss.item()

                      w_logps = model.forward(inputs[:,3,...])
                      w_batch_loss = criterion(w_logps, labels)
                      test_loss += w_batch_loss.item()

                      logps = (n_logps + e_logps + s_logps + w_logps)/4
                      
                      ps = torch.exp(logps)
                      top_p, top_class = ps.topk(1, dim=1)
                      equals = top_class == labels.view(*top_class.shape)
                      accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
              train_losses.append(running_loss/len(train_loader))
              test_losses.append(test_loss/len(test_loader))     
              accs.append(accuracy/len(test_loader))               
              print(f"Epoch {epoch+1}/{epochs}.. "
                    f"Train loss: {running_loss/print_every:.3f}.. "
                    f"Test loss: {test_loss/len(test_loader):.3f}.. "
                    f"Test accuracy: {accuracy/len(test_loader):.3f}")
              
              running_loss = 0
              model.train()
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b0-355c32eb.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b0-355c32eb.pth
# HBox(children=(FloatProgress(value=0.0, max=21388428.0), HTML(value='')))
# Loaded pretrained weights for efficientnet-b0
# Epoch 1/1.. Train loss: 9.145.. Test loss: 8.670.. Test accuracy: 0.197
# Epoch 1/1.. Train loss: 9.049.. Test loss: 9.079.. Test accuracy: 0.146
# Epoch 1/1.. Train loss: 8.598.. Test loss: 9.196.. Test accuracy: 0.145
# Epoch 1/1.. Train loss: 8.577.. Test loss: 8.614.. Test accuracy: 0.192
# Epoch 1/1.. Train loss: 8.022.. Test loss: 8.084.. Test accuracy: 0.268
# Epoch 1/1.. Train loss: 7.927.. Test loss: 7.949.. Test accuracy: 0.334
# Epoch 1/1.. Train loss: 7.862.. Test loss: 7.794.. Test accuracy: 0.343
# Epoch 1/1.. Train loss: 7.858.. Test loss: 7.518.. Test accuracy: 0.400
# Epoch 1/1.. Train loss: 7.752.. Test loss: 7.294.. Test accuracy: 0.440
# Epoch 1/1.. Train loss: 7.743.. Test loss: 7.434.. Test accuracy: 0.364
# Epoch 1/1.. Train loss: 7.511.. Test loss: 7.302.. Test accuracy: 0.406
# Epoch 1/1.. Train loss: 7.549.. Test loss: 7.240.. Test accuracy: 0.414
# Epoch 1/1.. Train loss: 7.450.. Test loss: 7.045.. Test accuracy: 0.466
# Epoch 1/1.. Train loss: 7.347.. Test loss: 7.110.. Test accuracy: 0.441
# Epoch 1/1.. Train loss: 7.272.. Test loss: 6.992.. Test accuracy: 0.459
# Epoch 1/1.. Train loss: 7.509.. Test loss: 6.938.. Test accuracy: 0.480
# Epoch 1/1.. Train loss: 7.100.. Test loss: 7.074.. Test accuracy: 0.425
# Epoch 1/1.. Train loss: 7.483.. Test loss: 6.913.. Test accuracy: 0.474
# Epoch 1/1.. Train loss: 7.215.. Test loss: 6.765.. Test accuracy: 0.499
# Epoch 1/1.. Train loss: 7.298.. Test loss: 6.777.. Test accuracy: 0.488
# Epoch 1/1.. Train loss: 7.053.. Test loss: 6.912.. Test accuracy: 0.472
# Epoch 1/1.. Train loss: 7.530.. Test loss: 6.870.. Test accuracy: 0.482
# Epoch 1/1.. Train loss: 7.147.. Test loss: 6.886.. Test accuracy: 0.481
# Epoch 1/1.. Train loss: 7.039.. Test loss: 6.722.. Test accuracy: 0.486
# Epoch 1/1.. Train loss: 7.294.. Test loss: 6.720.. Test accuracy: 0.500
# Epoch 1/1.. Train loss: 7.149.. Test loss: 6.554.. Test accuracy: 0.523
# Epoch 1/1.. Train loss: 7.323.. Test loss: 6.585.. Test accuracy: 0.522
# Epoch 1/1.. Train loss: 6.905.. Test loss: 6.626.. Test accuracy: 0.519
# Epoch 1/1.. Train loss: 7.052.. Test loss: 6.531.. Test accuracy: 0.518
# Epoch 1/1.. Train loss: 6.891.. Test loss: 6.521.. Test accuracy: 0.522
# Epoch 1/1.. Train loss: 6.627.. Test loss: 6.588.. Test accuracy: 0.505
# Epoch 1/1.. Train loss: 7.142.. Test loss: 6.439.. Test accuracy: 0.532
# Epoch 1/1.. Train loss: 6.987.. Test loss: 6.427.. Test accuracy: 0.544
# Epoch 1/1.. Train loss: 7.049.. Test loss: 6.489.. Test accuracy: 0.537
# Epoch 1/1.. Train loss: 6.788.. Test loss: 6.398.. Test accuracy: 0.546
# Epoch 1/1.. Train loss: 6.793.. Test loss: 6.431.. Test accuracy: 0.530
# Epoch 1/1.. Train loss: 6.657.. Test loss: 6.316.. Test accuracy: 0.550
# Epoch 1/1.. Train loss: 6.856.. Test loss: 6.304.. Test accuracy: 0.546
# Epoch 1/1.. Train loss: 6.772.. Test loss: 6.573.. Test accuracy: 0.505
# Epoch 1/1.. Train loss: 7.030.. Test loss: 6.521.. Test accuracy: 0.516
# Epoch 1/1.. Train loss: 7.048.. Test loss: 6.364.. Test accuracy: 0.549
# Epoch 1/1.. Train loss: 6.988.. Test loss: 6.352.. Test accuracy: 0.538
# Epoch 1/1.. Train loss: 6.818.. Test loss: 6.260.. Test accuracy: 0.556
# Epoch 1/1.. Train loss: 6.851.. Test loss: 6.207.. Test accuracy: 0.565
# Epoch 1/1.. Train loss: 6.843.. Test loss: 6.191.. Test accuracy: 0.566
# Epoch 1/1.. Train loss: 7.051.. Test loss: 6.308.. Test accuracy: 0.534
# Epoch 1/1.. Train loss: 6.651.. Test loss: 6.411.. Test accuracy: 0.506
# Epoch 1/1.. Train loss: 7.014.. Test loss: 6.277.. Test accuracy: 0.562
# Epoch 1/1.. Train loss: 6.829.. Test loss: 6.239.. Test accuracy: 0.565
# Epoch 1/1.. Train loss: 6.734.. Test loss: 6.297.. Test accuracy: 0.545
# Epoch 1/1.. Train loss: 6.846.. Test loss: 6.316.. Test accuracy: 0.525
# Epoch 1/1.. Train loss: 6.897.. Test loss: 6.115.. Test accuracy: 0.592
# Epoch 1/1.. Train loss: 6.854.. Test loss: 6.209.. Test accuracy: 0.554
# Epoch 1/1.. Train loss: 6.754.. Test loss: 6.210.. Test accuracy: 0.556
# Epoch 1/1.. Train loss: 6.722.. Test loss: 6.114.. Test accuracy: 0.578
# Epoch 1/1.. Train loss: 6.697.. Test loss: 6.222.. Test accuracy: 0.561
# Epoch 1/1.. Train loss: 6.925.. Test loss: 6.176.. Test accuracy: 0.568
# Epoch 1/1.. Train loss: 6.835.. Test loss: 6.262.. Test accuracy: 0.546
# Epoch 1/1.. Train loss: 6.646.. Test loss: 6.254.. Test accuracy: 0.550
# Epoch 1/1.. Train loss: 6.871.. Test loss: 6.119.. Test accuracy: 0.568
# Epoch 1/1.. Train loss: 6.424.. Test loss: 6.016.. Test accuracy: 0.593
# Epoch 1/1.. Train loss: 6.646.. Test loss: 6.064.. Test accuracy: 0.586
# Epoch 1/1.. Train loss: 6.879.. Test loss: 6.033.. Test accuracy: 0.578
# Epoch 1/1.. Train loss: 6.615.. Test loss: 6.090.. Test accuracy: 0.594
# Epoch 1/1.. Train loss: 6.584.. Test loss: 6.038.. Test accuracy: 0.603
# Epoch 1/1.. Train loss: 6.583.. Test loss: 6.072.. Test accuracy: 0.589
# Epoch 1/1.. Train loss: 6.621.. Test loss: 6.029.. Test accuracy: 0.589
# Epoch 1/1.. Train loss: 6.761.. Test loss: 5.943.. Test accuracy: 0.608
# Epoch 1/1.. Train loss: 6.746.. Test loss: 6.015.. Test accuracy: 0.597
# Epoch 1/1.. Train loss: 6.490.. Test loss: 6.026.. Test accuracy: 0.574
# Epoch 1/1.. Train loss: 6.333.. Test loss: 5.914.. Test accuracy: 0.588
# Epoch 1/1.. Train loss: 6.514.. Test loss: 5.979.. Test accuracy: 0.599
# Epoch 1/1.. Train loss: 6.629.. Test loss: 5.919.. Test accuracy: 0.606
# Epoch 1/1.. Train loss: 6.563.. Test loss: 6.017.. Test accuracy: 0.578
# Epoch 1/1.. Train loss: 6.402.. Test loss: 6.039.. Test accuracy: 0.577
# Epoch 1/1.. Train loss: 6.395.. Test loss: 6.105.. Test accuracy: 0.542
# Epoch 1/1.. Train loss: 6.681.. Test loss: 5.877.. Test accuracy: 0.611
# Epoch 1/1.. Train loss: 6.758.. Test loss: 5.825.. Test accuracy: 0.629
# Epoch 1/1.. Train loss: 6.510.. Test loss: 5.858.. Test accuracy: 0.624
# Epoch 1/1.. Train loss: 6.242.. Test loss: 5.852.. Test accuracy: 0.611
# Epoch 1/1.. Train loss: 6.364.. Test loss: 5.853.. Test accuracy: 0.606
# Epoch 1/1.. Train loss: 6.260.. Test loss: 5.900.. Test accuracy: 0.593
# Epoch 1/1.. Train loss: 6.712.. Test loss: 5.870.. Test accuracy: 0.601
# Epoch 1/1.. Train loss: 6.705.. Test loss: 5.916.. Test accuracy: 0.599
# Epoch 1/1.. Train loss: 6.296.. Test loss: 5.882.. Test accuracy: 0.608
# Epoch 1/1.. Train loss: 6.700.. Test loss: 5.814.. Test accuracy: 0.622
# Epoch 1/1.. Train loss: 6.485.. Test loss: 5.911.. Test accuracy: 0.603
# Epoch 1/1.. Train loss: 6.679.. Test loss: 5.790.. Test accuracy: 0.627
# Epoch 1/1.. Train loss: 6.448.. Test loss: 5.889.. Test accuracy: 0.610
# Epoch 1/1.. Train loss: 6.351.. Test loss: 5.763.. Test accuracy: 0.630
# Epoch 1/1.. Train loss: 6.389.. Test loss: 5.793.. Test accuracy: 0.617
# Epoch 1/1.. Train loss: 6.344.. Test loss: 5.798.. Test accuracy: 0.619
# Epoch 1/1.. Train loss: 6.248.. Test loss: 5.792.. Test accuracy: 0.603
# Epoch 1/1.. Train loss: 6.408.. Test loss: 5.717.. Test accuracy: 0.622
# Epoch 1/1.. Train loss: 6.115.. Test loss: 5.732.. Test accuracy: 0.635
# Epoch 1/1.. Train loss: 6.138.. Test loss: 5.669.. Test accuracy: 0.637
# Epoch 1/1.. Train loss: 6.513.. Test loss: 5.698.. Test accuracy: 0.637
# Epoch 1/1.. Train loss: 6.151.. Test loss: 5.732.. Test accuracy: 0.631
# Epoch 1/1.. Train loss: 6.534.. Test loss: 5.739.. Test accuracy: 0.607
# Epoch 1/1.. Train loss: 6.719.. Test loss: 5.786.. Test accuracy: 0.626

# %%
torch.save(model, "effnetb0.pt")

# %% [markdown]
# ## Predictions from pretrained guy

# %%
#pretrained = models.resnet18(pretrained=False)
#pretrained.fc = nn.Sequential(nn.Linear(512, 256),
#                                 nn.ReLU(),
#                                 nn.Dropout(0.2),
#                                 nn.Linear(256, 10),
#                                 nn.LogSoftmax(dim=1))
#pretrained.load_state_dict(torch.load("resnetsmalldataset"))
# pretrained = EfficientNet.from_pretrained('efficientnet-b0')
    
# pretrained._fc = nn.Sequential(nn.Linear(1792, 256),
#                                  nn.ReLU(),
#                                  nn.Dropout(0.2),
#                                  nn.Linear(256, 10),
#                                  nn.LogSoftmax(dim=1))
pretrained = torch.load("effnetb0(1).pt")
pretrained.eval()
images, labels = next(iter(test_loader))

device = torch.device("cuda" if torch.cuda.is_available() 
                                  else "cpu")
images, labels = images.to(device), labels.to(device)
# Out:
# Loaded pretrained weights for efficientnet-b0

# %%
with torch.no_grad():
  visualize_example(images, 10, True)
  smax = pretrained.forward(images[10])
  comb = smax.mean(axis=0)
  preds = smax.argmax(axis=1)
  comb_preds = comb.argmax()
  real_labels = dict((v, k) for k, v in dataset.labels.items())
  print(f"Actual province: {real_labels[labels[10].item()]}")
  print(f"North prediction: {real_labels[preds[0].item()]}")
  print(f"East prediction: {real_labels[preds[1].item()]}")
  print(f"South prediction: {real_labels[preds[2].item()]}")
  print(f"West prediction: {real_labels[preds[3].item()]}")
  print(f"Combined prediction: {real_labels[comb_preds.item()]}")
# Out:
# <PIL.Image.Image image mode=RGB size=1024x256 at 0x7F7CAA3719D0>
# Actual province: BritishColumbia
# North prediction: BritishColumbia
# East prediction: NovaScotia
# South prediction: Saskatchewan
# West prediction: Alberta
# Combined prediction: BritishColumbia

# %%
with torch.no_grad():
  visualize_example(images, 5, True)
  smax = pretrained.forward(images[5])
  comb = smax.mean(axis=0)
  preds = smax.argmax(axis=1)
  comb_preds = comb.argmax()
  real_labels = dict((v, k) for k, v in dataset.labels.items())
  print(f"Actual province: {real_labels[labels[5].item()]}")
  print(f"North prediction: {real_labels[preds[0].item()]}")
  print(f"East prediction: {real_labels[preds[1].item()]}")
  print(f"South prediction: {real_labels[preds[2].item()]}")
  print(f"West prediction: {real_labels[preds[3].item()]}")
  print(f"Combined prediction: {real_labels[comb_preds.item()]}")
# Out:
# <PIL.Image.Image image mode=RGB size=1024x256 at 0x7F7C4AAA8BD0>
# Actual province: Manitoba
# North prediction: Manitoba
# East prediction: Manitoba
# South prediction: Manitoba
# West prediction: Manitoba
# Combined prediction: Manitoba

# %%
with torch.no_grad():
  visualize_example(images, 20, True)
  smax = pretrained.forward(images[20])
  comb = smax.mean(axis=0)
  preds = smax.argmax(axis=1)
  comb_preds = comb.argmax()
  real_labels = dict((v, k) for k, v in dataset.labels.items())
  print(f"Actual province: {real_labels[labels[20].item()]}")
  print(f"North prediction: {real_labels[preds[0].item()]}")
  print(f"East prediction: {real_labels[preds[1].item()]}")
  print(f"South prediction: {real_labels[preds[2].item()]}")
  print(f"West prediction: {real_labels[preds[3].item()]}")
  print(f"Combined prediction: {real_labels[comb_preds.item()]}")
# Out:
# <PIL.Image.Image image mode=RGB size=1024x256 at 0x7F7C4F4A8690>
# Actual province: Quebec
# North prediction: Quebec
# East prediction: Ontario
# South prediction: Manitoba
# West prediction: Ontario
# Combined prediction: Ontario

# %%
#pretrained = torch.load("effnetb0.pt").cuda().eval()

# %%
pretrained = model
pred_counts = defaultdict(int)
pred_correct = defaultdict(int)
pred_counts = defaultdict(int)
pred_correct = defaultdict(int)
real_labels = dict((v, k) for k, v in dataset.labels.items())

for i, (inputs, labels) in enumerate(val_loader):
    inputs, labels = inputs.cuda(), labels.cuda()

    n_smax = pretrained.forward(inputs[:,0,...])
    e_smax = pretrained.forward(inputs[:,1,...])
    s_smax = pretrained.forward(inputs[:,2,...])
    w_smax = pretrained.forward(inputs[:,3,...])
    comb = (n_smax+e_smax+s_smax+w_smax)/4

    n_pred = n_smax.argmax(axis=1)
    e_pred = e_smax.argmax(axis=1)
    s_pred = s_smax.argmax(axis=1)
    w_pred = w_smax.argmax(axis=1)
    comb_pred = comb.argmax(axis=1)

    correct = comb_pred == labels
    for j, corr in enumerate(correct):
        pred_correct[real_labels[labels[j].item()]] += int(corr)
        pred_counts[real_labels[labels[j].item()]] += 1


for k, v in pred_counts.items():
    print(f"{k} accuracy: {pred_correct[k]/v:.4f}")
print(f"Overall accuracy: {sum(pred_correct.values())/sum(pred_counts.values())}")
# Out:
# PEI accuracy: 0.8338
# Saskatchewan accuracy: 0.6469
# Alberta accuracy: 0.6131
# Quebec accuracy: 0.3117
# Ontario accuracy: 0.3056
# Manitoba accuracy: 0.5707
# NewfoundlandandLabrador accuracy: 0.7022
# NewBrunswick accuracy: 0.4654
# NovaScotia accuracy: 0.5981
# BritishColumbia accuracy: 0.8238
# Overall accuracy: 0.59325
